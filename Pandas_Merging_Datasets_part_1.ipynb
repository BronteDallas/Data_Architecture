# %% [markdown]
# <a href="https://colab.research.google.com/github/BronteDallas/Data_Architecture_-_Machine_Learning/blob/main/Pandas_Merging_Datasets_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"hello".capitalize()
# Out:
# 'Hello'

# %% [markdown]
# # MPG Cars
#
# Check out [Cars Exercises Video Tutorial](https://www.youtube.com/watch?v=avzLRBxoguU&list=PLgJhDSE2ZLxaY_DigHeiIDC1cD09rXgJv&index=3) to watch a data scientist go through the exercises

# %% [markdown]
# ### Introduction:
#
# The following exercise utilizes data from [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Auto+MPG)
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv).

# %% [markdown]
#    ### Step 3. Assign each to a to a variable called cars1 and cars2

# %%
cars1 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv")
cars2 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv")

print(cars1.head())
print(cars2.head())
# Out:
#     mpg  cylinders  displacement  ... Unnamed: 11  Unnamed: 12  Unnamed: 13
# 0  18.0          8           307  ...         NaN          NaN          NaN
# 1  15.0          8           350  ...         NaN          NaN          NaN
# 2  18.0          8           318  ...         NaN          NaN          NaN
# 3  16.0          8           304  ...         NaN          NaN          NaN
# 4  17.0          8           302  ...         NaN          NaN          NaN
#
# [5 rows x 14 columns]
#     mpg  cylinders  displacement  ... model  origin                 car
# 0  33.0          4            91  ...    76       3         honda civic
# 1  20.0          6           225  ...    76       1      dodge aspen se
# 2  18.0          6           250  ...    76       1   ford granada ghia
# 3  18.5          6           250  ...    76       1  pontiac ventura sj
# 4  17.5          6           258  ...    76       1       amc pacer d/l
#
# [5 rows x 9 columns]

# %% [markdown]
# ### Step 4. Oops, it seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1 = cars1.loc[:, "mpg":"car"]
cars1.head()
# Out:
#     mpg  cylinders  displacement  ... model  origin                        car
# 0  18.0          8           307  ...    70       1  chevrolet chevelle malibu
# 1  15.0          8           350  ...    70       1          buick skylark 320
# 2  18.0          8           318  ...    70       1         plymouth satellite
# 3  16.0          8           304  ...    70       1              amc rebel sst
# 4  17.0          8           302  ...    70       1                ford torino
#
# [5 rows x 9 columns]

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
print(cars1.shape)
print(cars2.shape)
# Out:
# (198, 9)
# (200, 9)

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars = cars1.append(cars2)
cars
# Out:
#       mpg  cylinders  displacement  ... model  origin                        car
# 0    18.0          8           307  ...    70       1  chevrolet chevelle malibu
# 1    15.0          8           350  ...    70       1          buick skylark 320
# 2    18.0          8           318  ...    70       1         plymouth satellite
# 3    16.0          8           304  ...    70       1              amc rebel sst
# 4    17.0          8           302  ...    70       1                ford torino
# ..    ...        ...           ...  ...   ...     ...                        ...
# 195  27.0          4           140  ...    82       1            ford mustang gl
# 196  44.0          4            97  ...    82       2                  vw pickup
# 197  32.0          4           135  ...    82       1              dodge rampage
# 198  28.0          4           120  ...    82       1                ford ranger
# 199  31.0          4           119  ...    82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ### Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
nr_owners = np.random.randint(15000, high=73001, size=398, dtype='l')
nr_owners
# Out:
# array([65407, 67299, 62171, 19075, 41670, 53330, 70767, 58230, 65721,
#        34638, 38562, 66372, 22495, 58422, 27870, 49231, 63756, 47534,
#        40192, 43563, 60216, 60406, 23103, 30168, 17773, 36270, 48946,
#        32430, 45251, 56679, 63718, 34823, 42005, 28710, 67669, 41761,
#        34934, 61627, 24838, 49468, 37868, 58579, 63704, 66880, 71689,
#        31286, 39219, 61731, 63594, 36171, 58480, 29352, 60046, 45674,
#        15737, 17922, 44136, 28901, 46987, 20326, 70511, 29193, 65711,
#        38908, 31128, 46091, 67857, 55625, 38968, 52988, 51108, 23757,
#        62653, 66900, 42116, 68904, 61349, 63972, 16902, 25639, 58170,
#        31115, 20725, 28851, 63387, 29490, 68232, 64690, 40560, 39683,
#        35054, 61017, 47107, 55833, 34994, 37347, 37827, 52633, 25656,
#        29788, 42963, 68479, 63232, 42694, 45168, 15028, 63220, 25375,
#        55966, 62608, 43407, 48747, 23212, 53028, 56140, 36004, 57605,
#        17409, 20702, 42968, 58963, 51793, 40440, 28113, 61064, 30424,
#        42288, 41579, 71935, 38414, 50725, 37844, 42893, 47611, 22488,
#        38916, 39755, 20482, 38930, 24938, 72011, 56938, 28312, 42821,
#        65215, 29581, 21038, 65968, 40902, 30308, 65436, 22482, 25825,
#        26805, 21607, 50463, 33467, 37843, 58386, 31253, 69470, 71258,
#        15141, 62722, 30019, 35550, 27793, 59678, 63527, 28354, 62120,
#        25799, 30107, 18685, 56581, 18111, 56027, 30406, 54714, 15844,
#        18745, 51261, 60213, 21560, 39462, 61204, 68195, 39898, 24162,
#        18216, 45980, 57009, 18007, 34478, 67158, 16512, 41801, 58793,
#        45915, 22719, 58278, 69271, 29021, 24802, 68019, 39815, 72115,
#        61955, 54561, 26608, 49282, 69623, 67426, 20129, 22294, 15922,
#        29075, 57778, 72990, 32315, 42473, 30046, 69394, 29894, 24771,
#        39164, 43246, 54993, 31992, 35282, 22154, 28145, 15544, 22948,
#        18719, 23707, 16642, 59504, 19600, 46362, 51582, 57587, 57867,
#        47445, 71308, 55179, 59753, 58808, 48463, 15009, 34773, 46950,
#        27383, 29542, 44062, 46484, 18522, 34936, 53312, 44077, 42572,
#        65624, 60063, 39096, 68514, 65280, 45474, 70959, 61563, 47904,
#        23827, 48265, 49441, 56533, 65923, 37818, 28967, 20302, 44897,
#        41948, 26867, 17891, 72532, 67747, 47971, 70864, 54962, 58071,
#        27437, 40615, 18842, 72606, 16213, 25169, 20464, 58522, 33569,
#        57757, 64232, 26842, 49426, 37148, 31833, 29327, 37142, 15464,
#        68617, 56287, 55703, 25398, 41736, 65853, 25031, 43562, 28364,
#        25941, 52499, 30091, 29315, 45806, 42624, 23143, 49050, 21766,
#        23915, 57617, 55391, 40712, 17599, 37894, 38044, 31630, 64859,
#        54122, 15939, 57201, 39296, 68211, 28577, 69713, 54754, 54289,
#        33929, 28648, 28928, 22758, 46046, 34563, 68694, 30868, 68001,
#        59787, 68657, 56052, 46076, 43294, 33415, 57648, 51890, 57457,
#        43574, 57204, 22403, 62111, 72617, 66103, 31061, 23410, 26447,
#        64963, 20825, 65851, 69655, 66135, 45205, 63215, 48567, 24972,
#        61693, 35178, 51974, 54096, 28298, 37895, 40682, 61103, 37082,
#        46403, 46277, 61589, 54620, 55939, 40294, 51509, 33623, 48899,
#        72924, 71806])

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars['owners'] = nr_owners
cars.tail()
# Out:
#       mpg  cylinders  displacement  ... origin              car  owners
# 195  27.0          4           140  ...      1  ford mustang gl   51509
# 196  44.0          4            97  ...      2        vw pickup   33623
# 197  32.0          4           135  ...      1    dodge rampage   48899
# 198  28.0          4           120  ...      1      ford ranger   72924
# 199  31.0          4           119  ...      1       chevy s-10   71806
#
# [5 rows x 10 columns]
